# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
cd My\ Drive
# Out:
# /gdrive/My Drive

# %%
cd Colab\ Notebooks
# Out:
# /gdrive/My Drive/Colab Notebooks

# %%
cd NLP\ Task\ Data\ Set
# Out:
# /gdrive/My Drive/Colab Notebooks/NLP Task Data Set

# %%
ls
# Out:
# address_dataset_1.json  address_dataset_2.json  ReadMe.txt

# %%
import pandas as pd
data = pd.read_json("address_dataset_1.json",lines = True)

# %%
data.head()
# Out:
#                                              address        locality
# 0               House No. F-97 Wz-350,Virender Nagar  Virender Nagar
# 1  House No. Prop No Wz-68-A, Khasra Kh No 796 Vi...  Virender Nagar
# 2                House No. Vb-158 Ugf,Virender Nagar  Virender Nagar
# 3  House No. Prop No Wz-79C/1 Plot No G-1,Virende...  Virender Nagar
# 4                    House No. Vb-133,Virender Nagar  Virender Nagar
