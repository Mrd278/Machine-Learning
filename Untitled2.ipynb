# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = [0,1,-1,0,1,3,-3,-1,1,3,-3,-1,0,1,-1,0]
A = np.asarray(A)
A = A.reshape(4,4)
print(A)
# Out:
# [[ 0  1 -1  0]
#  [ 1  3 -3 -1]
#  [ 1  3 -3 -1]
#  [ 0  1 -1  0]]

# %%
# Out:
# (4, 4)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
cd My\ Drive
# Out:
# [Errno 2] No such file or directory: 'My Drive'
# /gdrive/My Drive

# %%
cd Colab\ Notebooks
# Out:
# /gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
#  Accident-Images-Analysis-Dataset-master/   Multi_Label_dataset/
#  Accidents0515.csv                         'NLP Task Data Set'/
#  Casualties0515.csv                         OpenCv.ipynb
#  cifar-10-batches-py/                       Untitled0.ipynb
#  contextCSVs/                               Untitled1.ipynb
#  Family.jpg                                 Untitled2.ipynb
#  haarcascade_frontalface_default.xml        Vehicles0515.csv
#  haarcascade_smile.xml

# %%
import cv2

img = cv2.imread("Family.jpg")

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
print(gray_img.shape)
# Out:
# (1225, 1633)

# %%
plt.imshow(A)

# %%
from google.colab.patches import cv2_imshow

gray_img = cv2.resize(gray_img,(4,4))

cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=4x4 at 0x7FE437A42080>

# %%
result = gray_img*A

result = cv2.resize(result,(40,40))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-2dd38ba0982d> in <module>()
#       1 result = gray_img*A
#       2
# ----> 3 result = cv2.resize(result,(40,40))
#
# error: OpenCV(3.4.3) /io/opencv/modules/imgproc/src/resize.cpp:3922: error: (-215:Assertion failed) func != 0 in function 'resize'

# %%
300*300*3*100 + 1
# Out:
# 27000001
